# %%
import pandas as pd
import numpy as np
import requests
import re
import time as tm
import json

###############   Url加载函数    #########################
#实现：通过request模拟请求获取url的页面html数据，这里是比较完整的一个url请求函数
#输入：url地址
#返回：解析后的url文本内容r.text
##########################################################
T1 = tm.time()
def fetchURL(url):
    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
    }
    try:
        r = requests.get(url,headers=headers)  #模拟http请求
        r.raise_for_status()        #请求结果状态
        return r.text
    except requests.HTTPError as e:
        print(e)
        print("HTTPError")
    except requests.RequestException as e:
        print(e)
    except:
        print("Unknown Error !")
        
###############   页面数据爬取函数    #########################
#实现：通过json解析html文本，获取所需信息：从B站游戏评论中获取评论内容，评分，时间，赞/踩，用户名，用户等级
#输入：html文本
#返回：commentlist，包含10条上述结果的二维数组。（每个页面有10条评论）
##########################################################
def parserHtml(html):
    s = json.loads(html)  #用json解析html文本
    #准备容器
    content=[]
    grade=[]
    publish_time=[]
    up_count=[]
    down_count=[]
    user_name=[]
    user_level=[]
    #抓取每一条评论记录的所需信息
    for i in range(10):
        try:
            comment = s['data']['list'][i]
            content.append(comment['content'])
            grade.append(comment['grade'])
            publish_time.append(comment['publish_time'])
            up_count.append(comment['up_count'])
            down_count.append(comment['down_count'])
            user_name.append(comment['user_name'])
            user_level.append(comment['user_level'])
        except:
            break
    #将本页面的10条记录合并保存下来，变成一个二维表格
    commentlist=[content,
                 grade,
                 publish_time,
                 up_count,
                 down_count,
                 user_name,
                 user_level]
    return commentlist      #返回这个页面的10条评论

#***********主程序************
#step 1 输入需要爬取的b站游戏的信息

app_id="200"    #王者荣耀的B站ID’200‘，每个游戏都有一个
page_total=50          #需要爬取的总页数

#准备容器
all_content=[]
all_grade=[]
all_publish_time=[]
all_up_count=[]
all_down_count=[]
all_user_name=[]
all_user_level=[]

print('*************************************************')
print('Grapping comment data of app:{0} from BiliBili...'.format(app_id))
print('*************************************************\n')

#step 2  爬取数据，循环爬取，每页获取10条评论数据
for pagenum in range(1,page_total+1):
    t1=tm.time()  #用于调试代码效率
    url="https://line1-h5-pc-api.biligame.com/game/comment/page?game_base_id={0}&rank_type=2&page_num={1}&page_size=10".format(app_id, pagenum)
    comment_page = fetchURL(url)  #加载url
    parsered_comment=parserHtml(comment_page) #解析一页
    
    #从解析后的json对象中获取所需要的信息
    all_content.extend(parsered_comment[0])
    all_grade.extend(parsered_comment[1])
    all_publish_time.extend(parsered_comment[2])
    all_up_count.extend(parsered_comment[3])
    all_down_count.extend(parsered_comment[4])    
    all_user_name.extend(parsered_comment[5])
    all_user_level.extend(parsered_comment[6])
    t2=tm.time()  #用于调试代码效率
    timing=t2-t1                                      
    print('Page %d grapped, %5.2f seconds used' % (pagenum,timing))  #输出爬取进度
    if pagenum%10 == 0:
            print('Taking a break... To avoid being detected')
            tm.sleep(5)
            
#step 3  爬取完成，整理并导出数据
result={"content" : all_content,
    "grade" : all_grade,
    "publish_time" : all_publish_time,
    "up_count" : all_up_count,
    "down_count" : all_down_count,
    "user_name" : all_user_name,
    "user_level" : all_user_level,
    } 
    
resultpd=pd.DataFrame(result)
print('\n*************************************************')
print('Comment grapping finished. %d comments grapped in total' % (len(resultpd['content'])))
resultpd.to_excel('Bili_comment_appid{}.xlsx'.format(app_id))
print('Written to 【Bili_comment_appid{}.xlsx】'.format(app_id))
print('*************************************************')
T2 = tm.time()
print('程序运行时间:%s秒' % ((T2 - T1)))
# Out:
# *************************************************
# Grapping comment data of app:200 from BiliBili...
# *************************************************
#
# Page 1 grapped,  1.58 seconds used
# Page 2 grapped,  1.14 seconds used
# Page 3 grapped,  0.87 seconds used
# Page 4 grapped,  0.92 seconds used
# Page 5 grapped,  1.21 seconds used
# Page 6 grapped,  0.89 seconds used
# Page 7 grapped,  0.92 seconds used
# Page 8 grapped,  0.91 seconds used
# Page 9 grapped,  1.25 seconds used
# Page 10 grapped,  1.11 seconds used
# Taking a break... To avoid being detected
# Page 11 grapped,  1.21 seconds used
# Page 12 grapped,  1.39 seconds used
# Page 13 grapped,  1.89 seconds used
# Page 14 grapped,  0.78 seconds used
# Page 15 grapped,  1.77 seconds used
# Page 16 grapped,  1.23 seconds used
# Page 17 grapped,  1.24 seconds used
# Page 18 grapped,  0.80 seconds used
# Page 19 grapped,  0.55 seconds used
# Page 20 grapped,  0.72 seconds used
# Taking a break... To avoid being detected
# Page 21 grapped,  0.43 seconds used
# Page 22 grapped,  0.96 seconds used
# Page 23 grapped,  1.37 seconds used
# Page 24 grapped,  0.88 seconds used
# Page 25 grapped,  1.05 seconds used
# Page 26 grapped,  1.15 seconds used
# Page 27 grapped,  1.32 seconds used
# Page 28 grapped,  0.71 seconds used
# Page 29 grapped,  1.03 seconds used
# Page 30 grapped,  1.27 seconds used
# Taking a break... To avoid being detected
# Page 31 grapped,  1.15 seconds used
# Page 32 grapped,  0.60 seconds used
# Page 33 grapped,  0.98 seconds used
# Page 34 grapped,  0.79 seconds used
# Page 35 grapped,  0.50 seconds used
# Page 36 grapped,  0.60 seconds used
# Page 37 grapped,  0.78 seconds used
# Page 38 grapped,  0.87 seconds used
# Page 39 grapped,  0.53 seconds used
# Page 40 grapped,  1.08 seconds used
# Taking a break... To avoid being detected
# Page 41 grapped,  0.43 seconds used
# Page 42 grapped,  0.32 seconds used
# Page 43 grapped,  0.34 seconds used
# Page 44 grapped,  0.28 seconds used
# Page 45 grapped,  0.32 seconds used
# Page 46 grapped,  0.43 seconds used
# Page 47 grapped,  0.32 seconds used
# Page 48 grapped,  0.85 seconds used
# Page 49 grapped,  1.74 seconds used
# Page 50 grapped,  0.81 seconds used
# Taking a break... To avoid being detected
#
# *************************************************
# Comment grapping finished. 500 comments grapped in total
# Written to 【Bili_comment_appid200.xlsx】
# *************************************************
# 程序运行时间:71.66904735565186秒

# %%
resultpd.head(50)
# Out:
#                                               content  grade  \
# 0           虽然经常都在玩王者可是这个游戏真的太糟糕了根本不让我赢\n如果不是充了钱我玩都不玩      2
# 1                                                无话可说      2
# 2                                             (◦˙▽˙◦)     10
# 3                                             *扎不多德勒！      2
# 4                                 垃圾游戏，我被安排了，给个一星不过分吧      2
# 5                                                非常好！     10
# 6                                        垃圾游戏，一星都不想给！      2
# 7        我去(⇀‸↼‶)三次五连就出了荣耀水晶了，我近期是不是能吃就多吃点了，不然没机会了？？！     10
# 8                嫦娥的翻牌都得翻全了才能到下一关，该不会只有我是这么倒霉的吧，我不信！！      8
# 9            快过年了，是不是该得给我们瑶瑶公主来件新衣呢，不要多华丽的，类似嫦娥的那套也行。     10
# 10                    傻卵游戏，傻卵玩家，什么**游戏，狗都不玩，**的一群**玩家      2
# 11  那个请问瑶和云中君的情侣皮什么时候考虑一下，我很想要，换蔡文姬和澜的也行，最近磕他们的糖磕上瘾了。     10
# 12                                               垃圾游戏      2
# 13               求你们不会玩嫦娥的玩家不要再玩嫦娥了，嫦娥这胜率现在都惨不忍睹了....      8
# 14           凭实力得到你们家客服的关爱礼包，一天连跪十几局，我也是蛮厉害的，下次不要再送了啊     10
# 15  已经不知道多少了，毁去了多少孩子的童年，只是沉迷在虚拟的实力之中，可游戏再怎么强，他们现实中...      2
# 16                                               报复社会     10
# 17  看到一条评论差点把我笑断气了，内容是：滴个声音好听的女孩子，段位别低于钻石，不然就玩不了排位...     10
# 18  新模式是什么阴间东西？五把队友中必有一个全局在泉水和一塔之间发呆的，四个队友每把都基本上是葫...      2
# 19  共赏芳华让我明白到，做人不要太贪，不然到最后，就妥妥的288皮了！！我那个后悔啊！！我的诸葛...     10
# 20      轰隆隆大作战其实还蛮好玩的，如果兰陵王能ban的话就更加美好了，所以你们懂我意思吗？！\n     10
# 21  游戏可能是好游戏，但不好的可能是我吧，别人家的野王giegie带着他的瑶妹追着别人杀疯了似的...     10
# 22        这个星期就给自己定个小目标，就一周上个10颗星星吧，要求不高，加油ヾ(◍°∇°◍)ﾉﾞ      8
# 23  感觉这个赛季打到王者20星就满足了，反正这个赛季都还没有开始划分王者后的段位，等下个赛季划分...     10
# 24                                             啥也不想说了      2
# 25                                             饿了，差评。      2
# 26  哦~看到你这评分我居然感到意外，你的水军哪去了？你的孝子哪去了？玩王者五年了，去年退的坑，还...      2
# 27            轰隆隆大作战是不是玩不起，在我出去的路里堆满炸弹是几个意思，有本事让我出去！！      8
# 28                                           点踩的没马！！！      2
# 29  有的英雄尽管很好看，但我就是不玩~其实也不是我不想玩，就是起步有点艰难，根本就看不懂技能解释...      8
# 30                                              就挺无聊的      2
# 31              暃什么时候可以上架啊，在体验服试玩过还不错，就是在正式服不知道会改成什么样     10
# 32  为什么要在睡觉前打一把游戏还想着赢了才睡？！这样的做法是大错特错的，咱们就不该想要在睡前赢一...      8
# 33                                               支持腾讯      2
# 34                                垃圾游戏垃圾公司，她妈屎一样的匹配机制      2
# 35                     这游戏一点也不氪，皮肤免费送，非常的好玩，非常建议大家游玩。     10
# 36                                               好！！！     10
# 37  SB玩意李信bug能不能修修啊合着你们南极贱畜的都是一群fw呗，还有司空震那个傻批霸体开大头...      2
# 38                                               狗都不玩      2
# 39                              现在的王者匹配机制比以前更恶心了，还玩什么      2
# 40                                           感觉画质不如原神      2
# 41                                吐了啊，爷青铜号排位咋还半天匹配不上人      4
# 42                                              垃圾游戏，      2
# 43                                    elo一天不改，评分一天不改。      2
# 44                                          麻了麻了，融号退游      2
# 45                                     每次玩王者总要去医院测测血压      6
# 46  王者现在的评分无奈的，为什么那么低，我想了想由以下因素，第一大要素游戏上的一方面有的队友不行...     10
# 47  排位把把碰到怨鬼说要送和整局挂机怎么打，情侣狗秀送人头秀队友怎么整，给你匹配人机不就行了，自...      4
# 48                                        匹配机制，恶心到炸😁😁      2
